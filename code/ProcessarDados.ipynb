# %%
import pandas as pd

# %%
data_ = pd.read_csv("../input/2021-04-27.csv")
data_
# Out:
#      sequencial_sessao data_sessao sigla_partido sigla_uf_partido  \
# 0                    1  2021-04-27           PSD               BA
# 1                    1  2021-04-27            PP               PI
# 2                    1  2021-04-27           PSD               BA
# 3                    1  2021-04-27            PP               PI
# 4                    1  2021-04-27           PSD               BA
# ..                 ...         ...           ...              ...
# 580                  1  2021-04-27          REDE               AP
# 581                  1  2021-04-27           PSD               AM
# 582                  1  2021-04-27           PSD               AM
# 583                  1  2021-04-27           MDB               AM
# 584                  1  2021-04-27           PSD               AM
#
#                          bloco_parlamentar    nome_discursante  \
# 0                                      NaN        OTTO ALENCAR
# ...
